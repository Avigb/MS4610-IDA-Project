# %%
import pandas as pd
import numpy as np
from mpl_toolkits import mplot3d
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.impute import KNNImputer
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler, MinMaxScaler, MaxAbsScaler, Normalizer
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB, BernoulliNB, MultinomialNB, ComplementNB
from sklearn.pipeline import make_pipeline
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix, ConfusionMatrixDisplay
from sklearn.cluster import KMeans
from tqdm.notebook import tqdm

# %%
X = pd.read_csv('./IDA project dataset/train_x.csv').drop(['ID'], axis=1)
y = pd.read_csv('./IDA project dataset/train_y.csv').drop(['ID'], axis=1)

X['y'] = y

X_nona = pd.get_dummies(X.dropna(), columns=['Loan type', 'Occupation type'])
y = X_nona['y'].to_numpy()
X = X_nona.drop(['y'], axis=1).to_numpy()

X.shape, y.shape
# Out:
# ((59238, 13), (59238,))

# %%
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2)

pca = PCA(n_components=5)
X_train_pca = pca.fit_transform(X_train)
X_val_pca = pca.transform(X_val)

# %% [markdown]
# # Decision Tree Classifier - gini index

# %%
F1_score = []
params = {}

X_train_pca_1 = X_train_pca[y_train==1]
X_train_pca_0 = X_train_pca[y_train==0]

for weight in tqdm(range(1, 11)):
    for min_samples_leaf in np.linspace(1, 15, 8, dtype=np.int32):
        print('===============================================================================')
        print('Class weights : [1, {0}], Min Samples Split : {1}'.format(weight, min_samples_leaf))

        X_train_norm = np.concatenate((X_train_pca_0, 
                                       np.tile(X_train_pca_1, (weight, 1))), axis=0)
        y_train_norm = np.concatenate((np.zeros(X_train_pca_0.shape[0]), 
                                       np.ones(weight*X_train_pca_1.shape[0])), axis=0)
        X_train_norm, y_train_norm = shuffle(X_train_norm, y_train_norm, random_state=0)

        clf = make_pipeline(StandardScaler(), DecisionTreeClassifier(min_samples_leaf=min_samples_leaf))
        clf.fit(X_train_norm, y_train_norm)
        y_val_pred = clf.predict(X_val_pca)

        val_acc = accuracy_score(y_val, y_val_pred)
        val_f1 = f1_score(y_val, y_val_pred)
        print("Validation set Accuracy : {0:.3f}".format(val_acc))
        print("Validation set F1 score : {0:.3f}".format(val_f1))
        conf_matrix = confusion_matrix(y_val, y_val_pred)
        disp = ConfusionMatrixDisplay(confusion_matrix=conf_matrix, display_labels=['0', '1'])
        disp.plot()
        plt.show()

        F1_score.append(val_f1)
        params[str(val_f1)] = [weight, min_samples_leaf]
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=10.0), HTML(value='')))
# ===============================================================================
# Class weights : [1, 1], Min Samples Split : 1
# Validation set Accuracy : 0.975
# Validation set F1 score : 0.816
# ===============================================================================
# Class weights : [1, 1], Min Samples Split : 3
# Validation set Accuracy : 0.978
# Validation set F1 score : 0.835
# ===============================================================================
# Class weights : [1, 1], Min Samples Split : 5
# Validation set Accuracy : 0.979
# Validation set F1 score : 0.842
# ===============================================================================
# Class weights : [1, 1], Min Samples Split : 7
# Validation set Accuracy : 0.980
# Validation set F1 score : 0.848
# ===============================================================================
# Class weights : [1, 1], Min Samples Split : 9
# Validation set Accuracy : 0.981
# Validation set F1 score : 0.855
# ===============================================================================
# Class weights : [1, 1], Min Samples Split : 11
# Validation set Accuracy : 0.981
# Validation set F1 score : 0.854
# ===============================================================================
# Class weights : [1, 1], Min Samples Split : 13
# Validation set Accuracy : 0.980
# Validation set F1 score : 0.846
# ===============================================================================
# Class weights : [1, 1], Min Samples Split : 15
# Validation set Accuracy : 0.980
# Validation set F1 score : 0.849
# ===============================================================================
# Class weights : [1, 2], Min Samples Split : 1
# Validation set Accuracy : 0.971
# Validation set F1 score : 0.795
# ===============================================================================
# Class weights : [1, 2], Min Samples Split : 3
# Validation set Accuracy : 0.971
# Validation set F1 score : 0.797
# ===============================================================================
# Class weights : [1, 2], Min Samples Split : 5
# Validation set Accuracy : 0.977
# Validation set F1 score : 0.836
# ===============================================================================
# Class weights : [1, 2], Min Samples Split : 7
# Validation set Accuracy : 0.975
# Validation set F1 score : 0.824
# ===============================================================================
# Class weights : [1, 2], Min Samples Split : 9
# Validation set Accuracy : 0.976
# Validation set F1 score : 0.828
# ===============================================================================
# Class weights : [1, 2], Min Samples Split : 11
# Validation set Accuracy : 0.977
# Validation set F1 score : 0.836
# ===============================================================================
# Class weights : [1, 2], Min Samples Split : 13
# Validation set Accuracy : 0.978
# Validation set F1 score : 0.838
# ===============================================================================
# Class weights : [1, 2], Min Samples Split : 15
# Validation set Accuracy : 0.977
# Validation set F1 score : 0.834
# ===============================================================================
# Class weights : [1, 3], Min Samples Split : 1
# Validation set Accuracy : 0.973
# Validation set F1 score : 0.805
# ===============================================================================
# Class weights : [1, 3], Min Samples Split : 3
# Validation set Accuracy : 0.972
# Validation set F1 score : 0.807
# ===============================================================================
# Class weights : [1, 3], Min Samples Split : 5
# Validation set Accuracy : 0.966
# Validation set F1 score : 0.772
# ===============================================================================
# Class weights : [1, 3], Min Samples Split : 7
# Validation set Accuracy : 0.974
# Validation set F1 score : 0.818
# ===============================================================================
# Class weights : [1, 3], Min Samples Split : 9
# Validation set Accuracy : 0.972
# Validation set F1 score : 0.808
# ===============================================================================
# Class weights : [1, 3], Min Samples Split : 11
# Validation set Accuracy : 0.972
# Validation set F1 score : 0.803
# ===============================================================================
# Class weights : [1, 3], Min Samples Split : 13
# Validation set Accuracy : 0.976
# Validation set F1 score : 0.827
# ===============================================================================
# Class weights : [1, 3], Min Samples Split : 15
# Validation set Accuracy : 0.975
# Validation set F1 score : 0.819
# ===============================================================================
# Class weights : [1, 4], Min Samples Split : 1
# Validation set Accuracy : 0.974
# Validation set F1 score : 0.810
# ===============================================================================
# Class weights : [1, 4], Min Samples Split : 3
# Validation set Accuracy : 0.973
# Validation set F1 score : 0.813
# ===============================================================================
# Class weights : [1, 4], Min Samples Split : 5
# Validation set Accuracy : 0.967
# Validation set F1 score : 0.782
# ===============================================================================
# Class weights : [1, 4], Min Samples Split : 7
# Validation set Accuracy : 0.964
# Validation set F1 score : 0.764
# ===============================================================================
# Class weights : [1, 4], Min Samples Split : 9
# Validation set Accuracy : 0.975
# Validation set F1 score : 0.823
# ===============================================================================
# Class weights : [1, 4], Min Samples Split : 11
# Validation set Accuracy : 0.972
# Validation set F1 score : 0.807
# ===============================================================================
# Class weights : [1, 4], Min Samples Split : 13
# Validation set Accuracy : 0.971
# Validation set F1 score : 0.800
# ===============================================================================
# Class weights : [1, 4], Min Samples Split : 15
# Validation set Accuracy : 0.970
# Validation set F1 score : 0.797
# ===============================================================================
# Class weights : [1, 5], Min Samples Split : 1
# Validation set Accuracy : 0.975
# Validation set F1 score : 0.817
# ===============================================================================
# Class weights : [1, 5], Min Samples Split : 3
# Validation set Accuracy : 0.974
# Validation set F1 score : 0.816
# ===============================================================================
# Class weights : [1, 5], Min Samples Split : 5
# Validation set Accuracy : 0.972
# Validation set F1 score : 0.808
# ===============================================================================
# Class weights : [1, 5], Min Samples Split : 7
# Validation set Accuracy : 0.965
# Validation set F1 score : 0.773
# ===============================================================================
# Class weights : [1, 5], Min Samples Split : 9
# Validation set Accuracy : 0.961
# Validation set F1 score : 0.753
# ===============================================================================
# Class weights : [1, 5], Min Samples Split : 11
# Validation set Accuracy : 0.970
# Validation set F1 score : 0.797
# ===============================================================================
# Class weights : [1, 5], Min Samples Split : 13
# Validation set Accuracy : 0.969
# Validation set F1 score : 0.790
# ===============================================================================
# Class weights : [1, 5], Min Samples Split : 15
# Validation set Accuracy : 0.966
# Validation set F1 score : 0.777
# ===============================================================================
# Class weights : [1, 6], Min Samples Split : 1
# Validation set Accuracy : 0.975
# Validation set F1 score : 0.820
# ===============================================================================
# Class weights : [1, 6], Min Samples Split : 3
# Validation set Accuracy : 0.975
# Validation set F1 score : 0.824
# ===============================================================================
# Class weights : [1, 6], Min Samples Split : 5
# Validation set Accuracy : 0.972
# Validation set F1 score : 0.808
# ===============================================================================
# Class weights : [1, 6], Min Samples Split : 7
# Validation set Accuracy : 0.968
# Validation set F1 score : 0.790
# ===============================================================================
# Class weights : [1, 6], Min Samples Split : 9
# Validation set Accuracy : 0.964
# Validation set F1 score : 0.771
# ===============================================================================
# Class weights : [1, 6], Min Samples Split : 11
# Validation set Accuracy : 0.960
# Validation set F1 score : 0.750
# ===============================================================================
# Class weights : [1, 6], Min Samples Split : 13
# Validation set Accuracy : 0.969
# Validation set F1 score : 0.795
# ===============================================================================
# Class weights : [1, 6], Min Samples Split : 15
# Validation set Accuracy : 0.968
# Validation set F1 score : 0.790
# ===============================================================================
# Class weights : [1, 7], Min Samples Split : 1
# Validation set Accuracy : 0.973
# Validation set F1 score : 0.802
# ===============================================================================
# Class weights : [1, 7], Min Samples Split : 3
# Validation set Accuracy : 0.974
# Validation set F1 score : 0.814
# ===============================================================================
# Class weights : [1, 7], Min Samples Split : 5
# Validation set Accuracy : 0.972
# Validation set F1 score : 0.804
# ===============================================================================
# Class weights : [1, 7], Min Samples Split : 7
# Validation set Accuracy : 0.969
# Validation set F1 score : 0.795
# ===============================================================================
# Class weights : [1, 7], Min Samples Split : 9
# Validation set Accuracy : 0.963
# Validation set F1 score : 0.762
# ===============================================================================
# Class weights : [1, 7], Min Samples Split : 11
# Validation set Accuracy : 0.961
# Validation set F1 score : 0.752
# ===============================================================================
# Class weights : [1, 7], Min Samples Split : 13
# Validation set Accuracy : 0.957
# Validation set F1 score : 0.731
# ===============================================================================
# Class weights : [1, 7], Min Samples Split : 15
# Validation set Accuracy : 0.968
# Validation set F1 score : 0.787
# ===============================================================================
# Class weights : [1, 8], Min Samples Split : 1
# Validation set Accuracy : 0.975
# Validation set F1 score : 0.817
# ===============================================================================
# Class weights : [1, 8], Min Samples Split : 3
# Validation set Accuracy : 0.977
# Validation set F1 score : 0.832
# ===============================================================================
# Class weights : [1, 8], Min Samples Split : 5
# Validation set Accuracy : 0.974
# Validation set F1 score : 0.818
# ===============================================================================
# Class weights : [1, 8], Min Samples Split : 7
# Validation set Accuracy : 0.970
# Validation set F1 score : 0.794
# ===============================================================================
# Class weights : [1, 8], Min Samples Split : 9
# Validation set Accuracy : 0.966
# Validation set F1 score : 0.775
# ===============================================================================
# Class weights : [1, 8], Min Samples Split : 11
# Validation set Accuracy : 0.962
# Validation set F1 score : 0.757
# ===============================================================================
# Class weights : [1, 8], Min Samples Split : 13
# Validation set Accuracy : 0.958
# Validation set F1 score : 0.737
# ===============================================================================
# Class weights : [1, 8], Min Samples Split : 15
# Validation set Accuracy : 0.953
# Validation set F1 score : 0.718
# ===============================================================================
# Class weights : [1, 9], Min Samples Split : 1
# Validation set Accuracy : 0.972
# Validation set F1 score : 0.792
# ===============================================================================
# Class weights : [1, 9], Min Samples Split : 3
# Validation set Accuracy : 0.973
# Validation set F1 score : 0.811
# ===============================================================================
# Class weights : [1, 9], Min Samples Split : 5
# Validation set Accuracy : 0.971
# Validation set F1 score : 0.803
# ===============================================================================
# Class weights : [1, 9], Min Samples Split : 7
# Validation set Accuracy : 0.968
# Validation set F1 score : 0.789
# ===============================================================================
# Class weights : [1, 9], Min Samples Split : 9
# Validation set Accuracy : 0.965
# Validation set F1 score : 0.774
# ===============================================================================
# Class weights : [1, 9], Min Samples Split : 11
# Validation set Accuracy : 0.961
# Validation set F1 score : 0.754
# ===============================================================================
# Class weights : [1, 9], Min Samples Split : 13
# Validation set Accuracy : 0.957
# Validation set F1 score : 0.736
# ===============================================================================
# Class weights : [1, 9], Min Samples Split : 15
# Validation set Accuracy : 0.954
# Validation set F1 score : 0.723
# ===============================================================================
# Class weights : [1, 10], Min Samples Split : 1
# Validation set Accuracy : 0.972
# Validation set F1 score : 0.798
# ===============================================================================
# Class weights : [1, 10], Min Samples Split : 3
# Validation set Accuracy : 0.973
# Validation set F1 score : 0.807
# ===============================================================================
# Class weights : [1, 10], Min Samples Split : 5
# Validation set Accuracy : 0.971
# Validation set F1 score : 0.802
# ===============================================================================
# Class weights : [1, 10], Min Samples Split : 7
# Validation set Accuracy : 0.970
# Validation set F1 score : 0.796
# ===============================================================================
# Class weights : [1, 10], Min Samples Split : 9
# Validation set Accuracy : 0.964
# Validation set F1 score : 0.768
# ===============================================================================
# Class weights : [1, 10], Min Samples Split : 11
# Validation set Accuracy : 0.960
# Validation set F1 score : 0.748
# ===============================================================================
# Class weights : [1, 10], Min Samples Split : 13
# Validation set Accuracy : 0.956
# Validation set F1 score : 0.732
# ===============================================================================
# Class weights : [1, 10], Min Samples Split : 15
# Validation set Accuracy : 0.955
# Validation set F1 score : 0.725

# %%
params[str(max(F1_score))], max(F1_score)
# Out:
# ([1, 9], 0.8549520766773163)

# %% [markdown]
# # Decision Tree Classifier - entropy

# %%
F1_score = []
params = {}

X_train_pca_1 = X_train_pca[y_train==1]
X_train_pca_0 = X_train_pca[y_train==0]

for weight in tqdm(range(1, 11)):
    for min_samples_leaf in np.linspace(1, 15, 8, dtype=np.int32):
        print('===============================================================================')
        print('Class weights : [1, {0}], Min Samples Split : {1}'.format(weight, min_samples_leaf))

        X_train_norm = np.concatenate((X_train_pca_0, 
                                       np.tile(X_train_pca_1, (weight, 1))), axis=0)
        y_train_norm = np.concatenate((np.zeros(X_train_pca_0.shape[0]), 
                                       np.ones(weight*X_train_pca_1.shape[0])), axis=0)
        X_train_norm, y_train_norm = shuffle(X_train_norm, y_train_norm, random_state=0)

        clf = make_pipeline(StandardScaler(), DecisionTreeClassifier(min_samples_leaf=min_samples_leaf,
                                                                     criterion='entropy'))
        clf.fit(X_train_norm, y_train_norm)
        y_val_pred = clf.predict(X_val_pca)

        val_acc = accuracy_score(y_val, y_val_pred)
        val_f1 = f1_score(y_val, y_val_pred)
        print("Validation set Accuracy : {0:.3f}".format(val_acc))
        print("Validation set F1 score : {0:.3f}".format(val_f1))
        conf_matrix = confusion_matrix(y_val, y_val_pred)
        disp = ConfusionMatrixDisplay(confusion_matrix=conf_matrix, display_labels=['0', '1'])
        disp.plot()
        plt.show()

        F1_score.append(val_f1)
        params[str(val_f1)] = [weight, min_samples_leaf]
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=10.0), HTML(value='')))
# ===============================================================================
# Class weights : [1, 1], Min Samples Split : 1
# Validation set Accuracy : 0.974
# Validation set F1 score : 0.796
# ===============================================================================
# Class weights : [1, 1], Min Samples Split : 3
# Validation set Accuracy : 0.978
# Validation set F1 score : 0.820
# ===============================================================================
# Class weights : [1, 1], Min Samples Split : 5
# Validation set Accuracy : 0.980
# Validation set F1 score : 0.840
# ===============================================================================
# Class weights : [1, 1], Min Samples Split : 7
# Validation set Accuracy : 0.979
# Validation set F1 score : 0.830
# ===============================================================================
# Class weights : [1, 1], Min Samples Split : 9
# Validation set Accuracy : 0.979
# Validation set F1 score : 0.826
# ===============================================================================
# Class weights : [1, 1], Min Samples Split : 11
# Validation set Accuracy : 0.981
# Validation set F1 score : 0.843
# ===============================================================================
# Class weights : [1, 1], Min Samples Split : 13
# Validation set Accuracy : 0.981
# Validation set F1 score : 0.841
# ===============================================================================
# Class weights : [1, 1], Min Samples Split : 15
# Validation set Accuracy : 0.981
# Validation set F1 score : 0.837
# ===============================================================================
# Class weights : [1, 2], Min Samples Split : 1
# Validation set Accuracy : 0.977
# Validation set F1 score : 0.816
# ===============================================================================
# Class weights : [1, 2], Min Samples Split : 3
# Validation set Accuracy : 0.975
# Validation set F1 score : 0.802
# ===============================================================================
# Class weights : [1, 2], Min Samples Split : 5
# Validation set Accuracy : 0.974
# Validation set F1 score : 0.801
# ===============================================================================
# Class weights : [1, 2], Min Samples Split : 7
# Validation set Accuracy : 0.974
# Validation set F1 score : 0.801
# ===============================================================================
# Class weights : [1, 2], Min Samples Split : 9
# Validation set Accuracy : 0.978
# Validation set F1 score : 0.825
# ===============================================================================
# Class weights : [1, 2], Min Samples Split : 11
# Validation set Accuracy : 0.976
# Validation set F1 score : 0.816
# ===============================================================================
# Class weights : [1, 2], Min Samples Split : 13
# Validation set Accuracy : 0.977
# Validation set F1 score : 0.818
# ===============================================================================
# Class weights : [1, 2], Min Samples Split : 15
# Validation set Accuracy : 0.977
# Validation set F1 score : 0.819
# ===============================================================================
# Class weights : [1, 3], Min Samples Split : 1
# Validation set Accuracy : 0.976
# Validation set F1 score : 0.808
# ===============================================================================
# Class weights : [1, 3], Min Samples Split : 3
# Validation set Accuracy : 0.975
# Validation set F1 score : 0.807
# ===============================================================================
# Class weights : [1, 3], Min Samples Split : 5
# Validation set Accuracy : 0.971
# Validation set F1 score : 0.783
# ===============================================================================
# Class weights : [1, 3], Min Samples Split : 7
# Validation set Accuracy : 0.976
# Validation set F1 score : 0.816
# ===============================================================================
# Class weights : [1, 3], Min Samples Split : 9
# Validation set Accuracy : 0.974
# Validation set F1 score : 0.801
# ===============================================================================
# Class weights : [1, 3], Min Samples Split : 11
# Validation set Accuracy : 0.971
# Validation set F1 score : 0.785
# ===============================================================================
# Class weights : [1, 3], Min Samples Split : 13
# Validation set Accuracy : 0.974
# Validation set F1 score : 0.802
# ===============================================================================
# Class weights : [1, 3], Min Samples Split : 15
# Validation set Accuracy : 0.974
# Validation set F1 score : 0.804
# ===============================================================================
# Class weights : [1, 4], Min Samples Split : 1
# Validation set Accuracy : 0.975
# Validation set F1 score : 0.802
# ===============================================================================
# Class weights : [1, 4], Min Samples Split : 3
# Validation set Accuracy : 0.974
# Validation set F1 score : 0.801
# ===============================================================================
# Class weights : [1, 4], Min Samples Split : 5
# Validation set Accuracy : 0.971
# Validation set F1 score : 0.784
# ===============================================================================
# Class weights : [1, 4], Min Samples Split : 7
# Validation set Accuracy : 0.969
# Validation set F1 score : 0.775
# ===============================================================================
# Class weights : [1, 4], Min Samples Split : 9
# Validation set Accuracy : 0.976
# Validation set F1 score : 0.816
# ===============================================================================
# Class weights : [1, 4], Min Samples Split : 11
# Validation set Accuracy : 0.972
# Validation set F1 score : 0.795
# ===============================================================================
# Class weights : [1, 4], Min Samples Split : 13
# Validation set Accuracy : 0.969
# Validation set F1 score : 0.777
# ===============================================================================
# Class weights : [1, 4], Min Samples Split : 15
# Validation set Accuracy : 0.967
# Validation set F1 score : 0.767
# ===============================================================================
# Class weights : [1, 5], Min Samples Split : 1
# Validation set Accuracy : 0.975
# Validation set F1 score : 0.803
# ===============================================================================
# Class weights : [1, 5], Min Samples Split : 3
# Validation set Accuracy : 0.975
# Validation set F1 score : 0.812
# ===============================================================================
# Class weights : [1, 5], Min Samples Split : 5
# Validation set Accuracy : 0.972
# Validation set F1 score : 0.792
# ===============================================================================
# Class weights : [1, 5], Min Samples Split : 7
# Validation set Accuracy : 0.967
# Validation set F1 score : 0.768
# ===============================================================================
# Class weights : [1, 5], Min Samples Split : 9
# Validation set Accuracy : 0.964
# Validation set F1 score : 0.751
# ===============================================================================
# Class weights : [1, 5], Min Samples Split : 11
# Validation set Accuracy : 0.970
# Validation set F1 score : 0.781
# ===============================================================================
# Class weights : [1, 5], Min Samples Split : 13
# Validation set Accuracy : 0.969
# Validation set F1 score : 0.776
# ===============================================================================
# Class weights : [1, 5], Min Samples Split : 15
# Validation set Accuracy : 0.966
# Validation set F1 score : 0.761
# ===============================================================================
# Class weights : [1, 6], Min Samples Split : 1
# Validation set Accuracy : 0.974
# Validation set F1 score : 0.799
# ===============================================================================
# Class weights : [1, 6], Min Samples Split : 3
# Validation set Accuracy : 0.973
# Validation set F1 score : 0.797
# ===============================================================================
# Class weights : [1, 6], Min Samples Split : 5
# Validation set Accuracy : 0.972
# Validation set F1 score : 0.791
# ===============================================================================
# Class weights : [1, 6], Min Samples Split : 7
# Validation set Accuracy : 0.967
# Validation set F1 score : 0.768
# ===============================================================================
# Class weights : [1, 6], Min Samples Split : 9
# Validation set Accuracy : 0.966
# Validation set F1 score : 0.760
# ===============================================================================
# Class weights : [1, 6], Min Samples Split : 11
# Validation set Accuracy : 0.963
# Validation set F1 score : 0.744
# ===============================================================================
# Class weights : [1, 6], Min Samples Split : 13
# Validation set Accuracy : 0.971
# Validation set F1 score : 0.786
# ===============================================================================
# Class weights : [1, 6], Min Samples Split : 15
# Validation set Accuracy : 0.969
# Validation set F1 score : 0.778
# ===============================================================================
# Class weights : [1, 7], Min Samples Split : 1
# Validation set Accuracy : 0.974
# Validation set F1 score : 0.792
# ===============================================================================
# Class weights : [1, 7], Min Samples Split : 3
# Validation set Accuracy : 0.975
# Validation set F1 score : 0.803
# ===============================================================================
# Class weights : [1, 7], Min Samples Split : 5
# Validation set Accuracy : 0.973
# Validation set F1 score : 0.799
# ===============================================================================
# Class weights : [1, 7], Min Samples Split : 7
# Validation set Accuracy : 0.970
# Validation set F1 score : 0.782
# ===============================================================================
# Class weights : [1, 7], Min Samples Split : 9
# Validation set Accuracy : 0.966
# Validation set F1 score : 0.763
# ===============================================================================
# Class weights : [1, 7], Min Samples Split : 11
# Validation set Accuracy : 0.965
# Validation set F1 score : 0.757
# ===============================================================================
# Class weights : [1, 7], Min Samples Split : 13
# Validation set Accuracy : 0.962
# Validation set F1 score : 0.739
# ===============================================================================
# Class weights : [1, 7], Min Samples Split : 15
# Validation set Accuracy : 0.970
# Validation set F1 score : 0.783
# ===============================================================================
# Class weights : [1, 8], Min Samples Split : 1
# Validation set Accuracy : 0.974
# Validation set F1 score : 0.794
# ===============================================================================
# Class weights : [1, 8], Min Samples Split : 3
# Validation set Accuracy : 0.975
# Validation set F1 score : 0.802
# ===============================================================================
# Class weights : [1, 8], Min Samples Split : 5
# Validation set Accuracy : 0.973
# Validation set F1 score : 0.795
# ===============================================================================
# Class weights : [1, 8], Min Samples Split : 7
# Validation set Accuracy : 0.973
# Validation set F1 score : 0.801
# ===============================================================================
# Class weights : [1, 8], Min Samples Split : 9
# Validation set Accuracy : 0.971
# Validation set F1 score : 0.790
# ===============================================================================
# Class weights : [1, 8], Min Samples Split : 11
# Validation set Accuracy : 0.969
# Validation set F1 score : 0.779
# ===============================================================================
# Class weights : [1, 8], Min Samples Split : 13
# Validation set Accuracy : 0.966
# Validation set F1 score : 0.761
# ===============================================================================
# Class weights : [1, 8], Min Samples Split : 15
# Validation set Accuracy : 0.963
# Validation set F1 score : 0.747
# ===============================================================================
# Class weights : [1, 9], Min Samples Split : 1
# Validation set Accuracy : 0.974
# Validation set F1 score : 0.791
# ===============================================================================
# Class weights : [1, 9], Min Samples Split : 3
# Validation set Accuracy : 0.974
# Validation set F1 score : 0.796
# ===============================================================================
# Class weights : [1, 9], Min Samples Split : 5
# Validation set Accuracy : 0.972
# Validation set F1 score : 0.793
# ===============================================================================
# Class weights : [1, 9], Min Samples Split : 7
# Validation set Accuracy : 0.972
# Validation set F1 score : 0.794
# ===============================================================================
# Class weights : [1, 9], Min Samples Split : 9
# Validation set Accuracy : 0.971
# Validation set F1 score : 0.790
# ===============================================================================
# Class weights : [1, 9], Min Samples Split : 11
# Validation set Accuracy : 0.969
# Validation set F1 score : 0.774
# ===============================================================================
# Class weights : [1, 9], Min Samples Split : 13
# Validation set Accuracy : 0.965
# Validation set F1 score : 0.753
# ===============================================================================
# Class weights : [1, 9], Min Samples Split : 15
# Validation set Accuracy : 0.964
# Validation set F1 score : 0.750
# ===============================================================================
# Class weights : [1, 10], Min Samples Split : 1
# Validation set Accuracy : 0.975
# Validation set F1 score : 0.794
# ===============================================================================
# Class weights : [1, 10], Min Samples Split : 3
# Validation set Accuracy : 0.974
# Validation set F1 score : 0.796
# ===============================================================================
# Class weights : [1, 10], Min Samples Split : 5
# Validation set Accuracy : 0.973
# Validation set F1 score : 0.794
# ===============================================================================
# Class weights : [1, 10], Min Samples Split : 7
# Validation set Accuracy : 0.971
# Validation set F1 score : 0.790
# ===============================================================================
# Class weights : [1, 10], Min Samples Split : 9
# Validation set Accuracy : 0.971
# Validation set F1 score : 0.787
# ===============================================================================
# Class weights : [1, 10], Min Samples Split : 11
# Validation set Accuracy : 0.969
# Validation set F1 score : 0.777
# ===============================================================================
# Class weights : [1, 10], Min Samples Split : 13
# Validation set Accuracy : 0.966
# Validation set F1 score : 0.763
# ===============================================================================
# Class weights : [1, 10], Min Samples Split : 15
# Validation set Accuracy : 0.964
# Validation set F1 score : 0.755

# %%
params[str(max(F1_score))], max(F1_score)
# Out:
# ([1, 11], 0.8432732316227463)
