# %%
import pandas as pd
import numpy as np
from mpl_toolkits import mplot3d
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.impute import KNNImputer
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler, MinMaxScaler, MaxAbsScaler, Normalizer
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB, BernoulliNB, MultinomialNB, ComplementNB
from sklearn.pipeline import make_pipeline
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix, ConfusionMatrixDisplay
from sklearn.cluster import KMeans
from tqdm.notebook import tqdm
import time

# %%
X = pd.read_csv('./IDA project dataset/train_x.csv').drop(['ID'], axis=1)
y = pd.read_csv('./IDA project dataset/train_y.csv').drop(['ID'], axis=1)

X['y'] = y

X_nona = pd.get_dummies(X.dropna(), columns=['Loan type', 'Occupation type'])
y = X_nona['y'].to_numpy()
X = X_nona.drop(['y'], axis=1).to_numpy()

X.shape, y.shape
# Out:
# ((59238, 13), (59238,))

# %%
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2)

pca = PCA(n_components=5)
X_train_pca = pca.fit_transform(X_train)
X_val_pca = pca.transform(X_val)

# %% [markdown]
# # kNN uniform weights

# %%
F1_score = []
params = {}

X_train_pca_1 = X_train_pca[y_train==1]
X_train_pca_0 = X_train_pca[y_train==0]

for weight in tqdm(range(1, 11)):
    for k in np.linspace(3, 25, 12, dtype=np.int32):
        print('===============================================================================')
        print('Class weights : [1, {0}], Neighbours : {1}'.format(weight, k))

        X_train_norm = np.concatenate((X_train_pca_0, 
                                       np.tile(X_train_pca_1, (weight, 1))), axis=0)
        y_train_norm = np.concatenate((np.zeros(X_train_pca_0.shape[0]), 
                                       np.ones(weight*X_train_pca_1.shape[0])), axis=0)
        X_train_norm, y_train_norm = shuffle(X_train_norm, y_train_norm, random_state=0)

        clf = make_pipeline(StandardScaler(), KNeighborsClassifier(n_neighbors=k, weights='uniform'))
        clf.fit(X_train_norm, y_train_norm)
        y_val_pred = clf.predict(X_val_pca)

        val_acc = accuracy_score(y_val, y_val_pred)
        val_f1 = f1_score(y_val, y_val_pred)
        print("Validation set Accuracy : {0:.3f}".format(val_acc))
        print("Validation set F1 score : {0:.3f}".format(val_f1))
        conf_matrix = confusion_matrix(y_val, y_val_pred)
        disp = ConfusionMatrixDisplay(confusion_matrix=conf_matrix, display_labels=['0', '1'])
        disp.plot()
        plt.show()

        F1_score.append(val_f1)
        params[str(val_f1)] = [weight, k]
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=10.0), HTML(value='')))
# ===============================================================================
# Class weights : [1, 1], Neighbours : 3
# Validation set Accuracy : 0.985
# Validation set F1 score : 0.877
# ===============================================================================
# Class weights : [1, 1], Neighbours : 5
# Validation set Accuracy : 0.985
# Validation set F1 score : 0.880
# ===============================================================================
# Class weights : [1, 1], Neighbours : 7
# Validation set Accuracy : 0.985
# Validation set F1 score : 0.873
# ===============================================================================
# Class weights : [1, 1], Neighbours : 9
# Validation set Accuracy : 0.984
# Validation set F1 score : 0.870
# ===============================================================================
# Class weights : [1, 1], Neighbours : 11
# Validation set Accuracy : 0.984
# Validation set F1 score : 0.862
# ===============================================================================
# Class weights : [1, 1], Neighbours : 13
# Validation set Accuracy : 0.983
# Validation set F1 score : 0.859
# ===============================================================================
# Class weights : [1, 1], Neighbours : 15
# Validation set Accuracy : 0.983
# Validation set F1 score : 0.858
# ===============================================================================
# Class weights : [1, 1], Neighbours : 17
# Validation set Accuracy : 0.983
# Validation set F1 score : 0.856
# ===============================================================================
# Class weights : [1, 1], Neighbours : 19
# Validation set Accuracy : 0.983
# Validation set F1 score : 0.854
# ===============================================================================
# Class weights : [1, 1], Neighbours : 21
# Validation set Accuracy : 0.982
# Validation set F1 score : 0.851
# ===============================================================================
# Class weights : [1, 1], Neighbours : 23
# Validation set Accuracy : 0.982
# Validation set F1 score : 0.846
# ===============================================================================
# Class weights : [1, 1], Neighbours : 25
# Validation set Accuracy : 0.982
# Validation set F1 score : 0.847
# ===============================================================================
# Class weights : [1, 2], Neighbours : 3
# Validation set Accuracy : 0.977
# Validation set F1 score : 0.830
# ===============================================================================
# Class weights : [1, 2], Neighbours : 5
# Validation set Accuracy : 0.984
# Validation set F1 score : 0.871
# ===============================================================================
# Class weights : [1, 2], Neighbours : 7
# Validation set Accuracy : 0.983
# Validation set F1 score : 0.869
# ===============================================================================
# Class weights : [1, 2], Neighbours : 9
# Validation set Accuracy : 0.985
# Validation set F1 score : 0.880
# ===============================================================================
# Class weights : [1, 2], Neighbours : 11
# Validation set Accuracy : 0.985
# Validation set F1 score : 0.878
# ===============================================================================
# Class weights : [1, 2], Neighbours : 13
# Validation set Accuracy : 0.984
# Validation set F1 score : 0.874
# ===============================================================================
# Class weights : [1, 2], Neighbours : 15
# Validation set Accuracy : 0.984
# Validation set F1 score : 0.872
# ===============================================================================
# Class weights : [1, 2], Neighbours : 17
# Validation set Accuracy : 0.984
# Validation set F1 score : 0.870
# ===============================================================================
# Class weights : [1, 2], Neighbours : 19
# Validation set Accuracy : 0.984
# Validation set F1 score : 0.869
# ===============================================================================
# Class weights : [1, 2], Neighbours : 21
# Validation set Accuracy : 0.983
# Validation set F1 score : 0.862
# ===============================================================================
# Class weights : [1, 2], Neighbours : 23
# Validation set Accuracy : 0.983
# Validation set F1 score : 0.865
# ===============================================================================
# Class weights : [1, 2], Neighbours : 25
# Validation set Accuracy : 0.983
# Validation set F1 score : 0.859
# ===============================================================================
# Class weights : [1, 3], Neighbours : 3
# Validation set Accuracy : 0.976
# Validation set F1 score : 0.826
# ===============================================================================
# Class weights : [1, 3], Neighbours : 5
# Validation set Accuracy : 0.972
# Validation set F1 score : 0.803
# ===============================================================================
# Class weights : [1, 3], Neighbours : 7
# Validation set Accuracy : 0.983
# Validation set F1 score : 0.867
# ===============================================================================
# Class weights : [1, 3], Neighbours : 9
# Validation set Accuracy : 0.983
# Validation set F1 score : 0.865
# ===============================================================================
# Class weights : [1, 3], Neighbours : 11
# Validation set Accuracy : 0.982
# Validation set F1 score : 0.861
# ===============================================================================
# Class weights : [1, 3], Neighbours : 13
# Validation set Accuracy : 0.984
# Validation set F1 score : 0.877
# ===============================================================================
# Class weights : [1, 3], Neighbours : 15
# Validation set Accuracy : 0.984
# Validation set F1 score : 0.874
# ===============================================================================
# Class weights : [1, 3], Neighbours : 17
# Validation set Accuracy : 0.983
# Validation set F1 score : 0.871
# ===============================================================================
# Class weights : [1, 3], Neighbours : 19
# Validation set Accuracy : 0.984
# Validation set F1 score : 0.869
# ===============================================================================
# Class weights : [1, 3], Neighbours : 21
# Validation set Accuracy : 0.983
# Validation set F1 score : 0.868
# ===============================================================================
# Class weights : [1, 3], Neighbours : 23
# Validation set Accuracy : 0.983
# Validation set F1 score : 0.868
# ===============================================================================
# Class weights : [1, 3], Neighbours : 25
# Validation set Accuracy : 0.984
# Validation set F1 score : 0.869
# ===============================================================================
# Class weights : [1, 4], Neighbours : 3
# Validation set Accuracy : 0.977
# Validation set F1 score : 0.827
# ===============================================================================
# Class weights : [1, 4], Neighbours : 5
# Validation set Accuracy : 0.972
# Validation set F1 score : 0.804
# ===============================================================================
# Class weights : [1, 4], Neighbours : 7
# Validation set Accuracy : 0.968
# Validation set F1 score : 0.781
# ===============================================================================
# Class weights : [1, 4], Neighbours : 9
# Validation set Accuracy : 0.982
# Validation set F1 score : 0.863
# ===============================================================================
# Class weights : [1, 4], Neighbours : 11
# Validation set Accuracy : 0.982
# Validation set F1 score : 0.860
# ===============================================================================
# Class weights : [1, 4], Neighbours : 13
# Validation set Accuracy : 0.982
# Validation set F1 score : 0.858
# ===============================================================================
# Class weights : [1, 4], Neighbours : 15
# Validation set Accuracy : 0.980
# Validation set F1 score : 0.850
# ===============================================================================
# Class weights : [1, 4], Neighbours : 17
# Validation set Accuracy : 0.983
# Validation set F1 score : 0.869
# ===============================================================================
# Class weights : [1, 4], Neighbours : 19
# Validation set Accuracy : 0.983
# Validation set F1 score : 0.865
# ===============================================================================
# Class weights : [1, 4], Neighbours : 21
# Validation set Accuracy : 0.982
# Validation set F1 score : 0.863
# ===============================================================================
# Class weights : [1, 4], Neighbours : 23
# Validation set Accuracy : 0.982
# Validation set F1 score : 0.862
# ===============================================================================
# Class weights : [1, 4], Neighbours : 25
# Validation set Accuracy : 0.983
# Validation set F1 score : 0.866
# ===============================================================================
# Class weights : [1, 5], Neighbours : 3
# Validation set Accuracy : 0.977
# Validation set F1 score : 0.830
# ===============================================================================
# Class weights : [1, 5], Neighbours : 5
# Validation set Accuracy : 0.972
# Validation set F1 score : 0.800
# ===============================================================================
# Class weights : [1, 5], Neighbours : 7
# Validation set Accuracy : 0.967
# Validation set F1 score : 0.778
# ===============================================================================
# Class weights : [1, 5], Neighbours : 9
# Validation set Accuracy : 0.963
# Validation set F1 score : 0.761
# ===============================================================================
# Class weights : [1, 5], Neighbours : 11
# Validation set Accuracy : 0.982
# Validation set F1 score : 0.859
# ===============================================================================
# Class weights : [1, 5], Neighbours : 13
# Validation set Accuracy : 0.981
# Validation set F1 score : 0.856
# ===============================================================================
# Class weights : [1, 5], Neighbours : 15
# Validation set Accuracy : 0.980
# Validation set F1 score : 0.850
# ===============================================================================
# Class weights : [1, 5], Neighbours : 17
# Validation set Accuracy : 0.979
# Validation set F1 score : 0.845
# ===============================================================================
# Class weights : [1, 5], Neighbours : 19
# Validation set Accuracy : 0.978
# Validation set F1 score : 0.836
# ===============================================================================
# Class weights : [1, 5], Neighbours : 21
# Validation set Accuracy : 0.982
# Validation set F1 score : 0.863
# ===============================================================================
# Class weights : [1, 5], Neighbours : 23
# Validation set Accuracy : 0.982
# Validation set F1 score : 0.862
# ===============================================================================
# Class weights : [1, 5], Neighbours : 25
# Validation set Accuracy : 0.980
# Validation set F1 score : 0.852
# ===============================================================================
# Class weights : [1, 6], Neighbours : 3
# Validation set Accuracy : 0.977
# Validation set F1 score : 0.828
# ===============================================================================
# Class weights : [1, 6], Neighbours : 5
# Validation set Accuracy : 0.971
# Validation set F1 score : 0.800
# ===============================================================================
# Class weights : [1, 6], Neighbours : 7
# Validation set Accuracy : 0.967
# Validation set F1 score : 0.778
# ===============================================================================
# Class weights : [1, 6], Neighbours : 9
# Validation set Accuracy : 0.962
# Validation set F1 score : 0.756
# ===============================================================================
# Class weights : [1, 6], Neighbours : 11
# Validation set Accuracy : 0.957
# Validation set F1 score : 0.734
# ===============================================================================
# Class weights : [1, 6], Neighbours : 13
# Validation set Accuracy : 0.981
# Validation set F1 score : 0.855
# ===============================================================================
# Class weights : [1, 6], Neighbours : 15
# Validation set Accuracy : 0.980
# Validation set F1 score : 0.851
# ===============================================================================
# Class weights : [1, 6], Neighbours : 17
# Validation set Accuracy : 0.980
# Validation set F1 score : 0.848
# ===============================================================================
# Class weights : [1, 6], Neighbours : 19
# Validation set Accuracy : 0.978
# Validation set F1 score : 0.835
# ===============================================================================
# Class weights : [1, 6], Neighbours : 21
# Validation set Accuracy : 0.976
# Validation set F1 score : 0.825
# ===============================================================================
# Class weights : [1, 6], Neighbours : 23
# Validation set Accuracy : 0.975
# Validation set F1 score : 0.818
# ===============================================================================
# Class weights : [1, 6], Neighbours : 25
# Validation set Accuracy : 0.980
# Validation set F1 score : 0.850
# ===============================================================================
# Class weights : [1, 7], Neighbours : 3
# Validation set Accuracy : 0.976
# Validation set F1 score : 0.827
# ===============================================================================
# Class weights : [1, 7], Neighbours : 5
# Validation set Accuracy : 0.972
# Validation set F1 score : 0.802
# ===============================================================================
# Class weights : [1, 7], Neighbours : 7
# Validation set Accuracy : 0.967
# Validation set F1 score : 0.776
# ===============================================================================
# Class weights : [1, 7], Neighbours : 9
# Validation set Accuracy : 0.962
# Validation set F1 score : 0.753
# ===============================================================================
# Class weights : [1, 7], Neighbours : 11
# Validation set Accuracy : 0.958
# Validation set F1 score : 0.735
# ===============================================================================
# Class weights : [1, 7], Neighbours : 13
# Validation set Accuracy : 0.953
# Validation set F1 score : 0.715
# ===============================================================================
# Class weights : [1, 7], Neighbours : 15
# Validation set Accuracy : 0.980
# Validation set F1 score : 0.851
# ===============================================================================
# Class weights : [1, 7], Neighbours : 17
# Validation set Accuracy : 0.979
# Validation set F1 score : 0.845
# ===============================================================================
# Class weights : [1, 7], Neighbours : 19
# Validation set Accuracy : 0.978
# Validation set F1 score : 0.835
# ===============================================================================
# Class weights : [1, 7], Neighbours : 21
# Validation set Accuracy : 0.976
# Validation set F1 score : 0.824
# ===============================================================================
# Class weights : [1, 7], Neighbours : 23
# Validation set Accuracy : 0.975
# Validation set F1 score : 0.818
# ===============================================================================
# Class weights : [1, 7], Neighbours : 25
# Validation set Accuracy : 0.973
# Validation set F1 score : 0.810
# ===============================================================================
# Class weights : [1, 8], Neighbours : 3
# Validation set Accuracy : 0.976
# Validation set F1 score : 0.826
# ===============================================================================
# Class weights : [1, 8], Neighbours : 5
# Validation set Accuracy : 0.972
# Validation set F1 score : 0.803
# ===============================================================================
# Class weights : [1, 8], Neighbours : 7
# Validation set Accuracy : 0.966
# Validation set F1 score : 0.774
# ===============================================================================
# Class weights : [1, 8], Neighbours : 9
# Validation set Accuracy : 0.962
# Validation set F1 score : 0.753
# ===============================================================================
# Class weights : [1, 8], Neighbours : 11
# Validation set Accuracy : 0.958
# Validation set F1 score : 0.735
# ===============================================================================
# Class weights : [1, 8], Neighbours : 13
# Validation set Accuracy : 0.953
# Validation set F1 score : 0.715
# ===============================================================================
# Class weights : [1, 8], Neighbours : 15
# Validation set Accuracy : 0.949
# Validation set F1 score : 0.697
# ===============================================================================
# Class weights : [1, 8], Neighbours : 17
# Validation set Accuracy : 0.979
# Validation set F1 score : 0.843
# ===============================================================================
# Class weights : [1, 8], Neighbours : 19
# Validation set Accuracy : 0.977
# Validation set F1 score : 0.832
# ===============================================================================
# Class weights : [1, 8], Neighbours : 21
# Validation set Accuracy : 0.976
# Validation set F1 score : 0.825
# ===============================================================================
# Class weights : [1, 8], Neighbours : 23
# Validation set Accuracy : 0.974
# Validation set F1 score : 0.817
# ===============================================================================
# Class weights : [1, 8], Neighbours : 25
# Validation set Accuracy : 0.973
# Validation set F1 score : 0.810
# ===============================================================================
# Class weights : [1, 9], Neighbours : 3
# Validation set Accuracy : 0.976
# Validation set F1 score : 0.823
# ===============================================================================
# Class weights : [1, 9], Neighbours : 5
# Validation set Accuracy : 0.972
# Validation set F1 score : 0.804
# ===============================================================================
# Class weights : [1, 9], Neighbours : 7
# Validation set Accuracy : 0.967
# Validation set F1 score : 0.776
# ===============================================================================
# Class weights : [1, 9], Neighbours : 9
# Validation set Accuracy : 0.962
# Validation set F1 score : 0.752
# ===============================================================================
# Class weights : [1, 9], Neighbours : 11
# Validation set Accuracy : 0.958
# Validation set F1 score : 0.734
# ===============================================================================
# Class weights : [1, 9], Neighbours : 13
# Validation set Accuracy : 0.952
# Validation set F1 score : 0.713
# ===============================================================================
# Class weights : [1, 9], Neighbours : 15
# Validation set Accuracy : 0.948
# Validation set F1 score : 0.696
# ===============================================================================
# Class weights : [1, 9], Neighbours : 17
# Validation set Accuracy : 0.944
# Validation set F1 score : 0.678
# ===============================================================================
# Class weights : [1, 9], Neighbours : 19
# Validation set Accuracy : 0.977
# Validation set F1 score : 0.830
# ===============================================================================
# Class weights : [1, 9], Neighbours : 21
# Validation set Accuracy : 0.976
# Validation set F1 score : 0.824
# ===============================================================================
# Class weights : [1, 9], Neighbours : 23
# Validation set Accuracy : 0.974
# Validation set F1 score : 0.815
# ===============================================================================
# Class weights : [1, 9], Neighbours : 25
# Validation set Accuracy : 0.973
# Validation set F1 score : 0.807
# ===============================================================================
# Class weights : [1, 10], Neighbours : 3
# Validation set Accuracy : 0.976
# Validation set F1 score : 0.822
# ===============================================================================
# Class weights : [1, 10], Neighbours : 5
# Validation set Accuracy : 0.972
# Validation set F1 score : 0.802
# ===============================================================================
# Class weights : [1, 10], Neighbours : 7
# Validation set Accuracy : 0.966
# Validation set F1 score : 0.774
# ===============================================================================
# Class weights : [1, 10], Neighbours : 9
# Validation set Accuracy : 0.962
# Validation set F1 score : 0.753
# ===============================================================================
# Class weights : [1, 10], Neighbours : 11
# Validation set Accuracy : 0.957
# Validation set F1 score : 0.733
# ===============================================================================
# Class weights : [1, 10], Neighbours : 13
# Validation set Accuracy : 0.953
# Validation set F1 score : 0.713
# ===============================================================================
# Class weights : [1, 10], Neighbours : 15
# Validation set Accuracy : 0.948
# Validation set F1 score : 0.696
# ===============================================================================
# Class weights : [1, 10], Neighbours : 17
# Validation set Accuracy : 0.944
# Validation set F1 score : 0.679
# ===============================================================================
# Class weights : [1, 10], Neighbours : 19
# Validation set Accuracy : 0.940
# Validation set F1 score : 0.664
# ===============================================================================
# Class weights : [1, 10], Neighbours : 21
# Validation set Accuracy : 0.976
# Validation set F1 score : 0.824
# ===============================================================================
# Class weights : [1, 10], Neighbours : 23
# Validation set Accuracy : 0.974
# Validation set F1 score : 0.813
# ===============================================================================
# Class weights : [1, 10], Neighbours : 25
# Validation set Accuracy : 0.973
# Validation set F1 score : 0.807

# %%
params[str(max(F1_score))], max(F1_score)
# Out:
# ([2, 9], 0.8797814207650273)

# %% [markdown]
# # kNN uniform distance

# %%
F1_score = []
params = {}

X_train_pca_1 = X_train_pca[y_train==1]
X_train_pca_0 = X_train_pca[y_train==0]

for weight in tqdm(range(1, 11)):
    for k in np.linspace(3, 25, 12, dtype=np.int32):
        print('===============================================================================')
        print('Class weights : [1, {0}], Neighbours : {1}'.format(weight, k))

        X_train_norm = np.concatenate((X_train_pca_0, 
                                       np.tile(X_train_pca_1, (weight, 1))), axis=0)
        y_train_norm = np.concatenate((np.zeros(X_train_pca_0.shape[0]), 
                                       np.ones(weight*X_train_pca_1.shape[0])), axis=0)
        X_train_norm, y_train_norm = shuffle(X_train_norm, y_train_norm, random_state=0)

        clf = make_pipeline(StandardScaler(), KNeighborsClassifier(n_neighbors=k, weights='distance'))
        clf.fit(X_train_norm, y_train_norm)
        y_val_pred = clf.predict(X_val_pca)

        val_acc = accuracy_score(y_val, y_val_pred)
        val_f1 = f1_score(y_val, y_val_pred)
        print("Validation set Accuracy : {0:.3f}".format(val_acc))
        print("Validation set F1 score : {0:.3f}".format(val_f1))
        conf_matrix = confusion_matrix(y_val, y_val_pred)
        disp = ConfusionMatrixDisplay(confusion_matrix=conf_matrix, display_labels=['0', '1'])
        disp.plot()
        plt.show()

        F1_score.append(val_f1)
        params[str(val_f1)] = [weight, k]
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=10.0), HTML(value='')))
# ===============================================================================
# Class weights : [1, 1], Neighbours : 3
# Validation set Accuracy : 0.985
# Validation set F1 score : 0.876
# ===============================================================================
# Class weights : [1, 1], Neighbours : 5
# Validation set Accuracy : 0.985
# Validation set F1 score : 0.880
# ===============================================================================
# Class weights : [1, 1], Neighbours : 7
# Validation set Accuracy : 0.985
# Validation set F1 score : 0.874
# ===============================================================================
# Class weights : [1, 1], Neighbours : 9
# Validation set Accuracy : 0.984
# Validation set F1 score : 0.869
# ===============================================================================
# Class weights : [1, 1], Neighbours : 11
# Validation set Accuracy : 0.984
# Validation set F1 score : 0.864
# ===============================================================================
# Class weights : [1, 1], Neighbours : 13
# Validation set Accuracy : 0.984
# Validation set F1 score : 0.863
# ===============================================================================
# Class weights : [1, 1], Neighbours : 15
# Validation set Accuracy : 0.983
# Validation set F1 score : 0.858
# ===============================================================================
# Class weights : [1, 1], Neighbours : 17
# Validation set Accuracy : 0.983
# Validation set F1 score : 0.860
# ===============================================================================
# Class weights : [1, 1], Neighbours : 19
# Validation set Accuracy : 0.983
# Validation set F1 score : 0.859
# ===============================================================================
# Class weights : [1, 1], Neighbours : 21
# Validation set Accuracy : 0.983
# Validation set F1 score : 0.856
# ===============================================================================
# Class weights : [1, 1], Neighbours : 23
# Validation set Accuracy : 0.983
# Validation set F1 score : 0.855
# ===============================================================================
# Class weights : [1, 1], Neighbours : 25
# Validation set Accuracy : 0.983
# Validation set F1 score : 0.853
# ===============================================================================
# Class weights : [1, 2], Neighbours : 3
# Validation set Accuracy : 0.977
# Validation set F1 score : 0.832
# ===============================================================================
# Class weights : [1, 2], Neighbours : 5
# Validation set Accuracy : 0.984
# Validation set F1 score : 0.872
# ===============================================================================
# Class weights : [1, 2], Neighbours : 7
# Validation set Accuracy : 0.984
# Validation set F1 score : 0.872
# ===============================================================================
# Class weights : [1, 2], Neighbours : 9
# Validation set Accuracy : 0.985
# Validation set F1 score : 0.882
# ===============================================================================
# Class weights : [1, 2], Neighbours : 11
# Validation set Accuracy : 0.985
# Validation set F1 score : 0.881
# ===============================================================================
# Class weights : [1, 2], Neighbours : 13
# Validation set Accuracy : 0.985
# Validation set F1 score : 0.877
# ===============================================================================
# Class weights : [1, 2], Neighbours : 15
# Validation set Accuracy : 0.984
# Validation set F1 score : 0.873
# ===============================================================================
# Class weights : [1, 2], Neighbours : 17
# Validation set Accuracy : 0.985
# Validation set F1 score : 0.874
# ===============================================================================
# Class weights : [1, 2], Neighbours : 19
# Validation set Accuracy : 0.984
# Validation set F1 score : 0.870
# ===============================================================================
# Class weights : [1, 2], Neighbours : 21
# Validation set Accuracy : 0.984
# Validation set F1 score : 0.869
# ===============================================================================
# Class weights : [1, 2], Neighbours : 23
# Validation set Accuracy : 0.984
# Validation set F1 score : 0.870
# ===============================================================================
# Class weights : [1, 2], Neighbours : 25
# Validation set Accuracy : 0.984
# Validation set F1 score : 0.870
# ===============================================================================
# Class weights : [1, 3], Neighbours : 3
# Validation set Accuracy : 0.977
# Validation set F1 score : 0.828
# ===============================================================================
# Class weights : [1, 3], Neighbours : 5
# Validation set Accuracy : 0.973
# Validation set F1 score : 0.809
# ===============================================================================
# Class weights : [1, 3], Neighbours : 7
# Validation set Accuracy : 0.982
# Validation set F1 score : 0.861
# ===============================================================================
# Class weights : [1, 3], Neighbours : 9
# Validation set Accuracy : 0.983
# Validation set F1 score : 0.866
# ===============================================================================
# Class weights : [1, 3], Neighbours : 11
# Validation set Accuracy : 0.983
# Validation set F1 score : 0.865
# ===============================================================================
# Class weights : [1, 3], Neighbours : 13
# Validation set Accuracy : 0.984
# Validation set F1 score : 0.873
# ===============================================================================
# Class weights : [1, 3], Neighbours : 15
# Validation set Accuracy : 0.984
# Validation set F1 score : 0.876
# ===============================================================================
# Class weights : [1, 3], Neighbours : 17
# Validation set Accuracy : 0.984
# Validation set F1 score : 0.873
# ===============================================================================
# Class weights : [1, 3], Neighbours : 19
# Validation set Accuracy : 0.984
# Validation set F1 score : 0.874
# ===============================================================================
# Class weights : [1, 3], Neighbours : 21
# Validation set Accuracy : 0.983
# Validation set F1 score : 0.868
# ===============================================================================
# Class weights : [1, 3], Neighbours : 23
# Validation set Accuracy : 0.983
# Validation set F1 score : 0.868
# ===============================================================================
# Class weights : [1, 3], Neighbours : 25
# Validation set Accuracy : 0.984
# Validation set F1 score : 0.871
# ===============================================================================
# Class weights : [1, 4], Neighbours : 3
# Validation set Accuracy : 0.977
# Validation set F1 score : 0.828
# ===============================================================================
# Class weights : [1, 4], Neighbours : 5
# Validation set Accuracy : 0.973
# Validation set F1 score : 0.808
# ===============================================================================
# Class weights : [1, 4], Neighbours : 7
# Validation set Accuracy : 0.969
# Validation set F1 score : 0.789
# ===============================================================================
# Class weights : [1, 4], Neighbours : 9
# Validation set Accuracy : 0.980
# Validation set F1 score : 0.846
# ===============================================================================
# Class weights : [1, 4], Neighbours : 11
# Validation set Accuracy : 0.982
# Validation set F1 score : 0.860
# ===============================================================================
# Class weights : [1, 4], Neighbours : 13
# Validation set Accuracy : 0.982
# Validation set F1 score : 0.859
# ===============================================================================
# Class weights : [1, 4], Neighbours : 15
# Validation set Accuracy : 0.981
# Validation set F1 score : 0.858
# ===============================================================================
# Class weights : [1, 4], Neighbours : 17
# Validation set Accuracy : 0.983
# Validation set F1 score : 0.866
# ===============================================================================
# Class weights : [1, 4], Neighbours : 19
# Validation set Accuracy : 0.983
# Validation set F1 score : 0.866
# ===============================================================================
# Class weights : [1, 4], Neighbours : 21
# Validation set Accuracy : 0.983
# Validation set F1 score : 0.868
# ===============================================================================
# Class weights : [1, 4], Neighbours : 23
# Validation set Accuracy : 0.983
# Validation set F1 score : 0.868
# ===============================================================================
# Class weights : [1, 4], Neighbours : 25
# Validation set Accuracy : 0.983
# Validation set F1 score : 0.867
# ===============================================================================
# Class weights : [1, 5], Neighbours : 3
# Validation set Accuracy : 0.977
# Validation set F1 score : 0.829
# ===============================================================================
# Class weights : [1, 5], Neighbours : 5
# Validation set Accuracy : 0.972
# Validation set F1 score : 0.805
# ===============================================================================
# Class weights : [1, 5], Neighbours : 7
# Validation set Accuracy : 0.968
# Validation set F1 score : 0.784
# ===============================================================================
# Class weights : [1, 5], Neighbours : 9
# Validation set Accuracy : 0.967
# Validation set F1 score : 0.776
# ===============================================================================
# Class weights : [1, 5], Neighbours : 11
# Validation set Accuracy : 0.978
# Validation set F1 score : 0.836
# ===============================================================================
# Class weights : [1, 5], Neighbours : 13
# Validation set Accuracy : 0.980
# Validation set F1 score : 0.849
# ===============================================================================
# Class weights : [1, 5], Neighbours : 15
# Validation set Accuracy : 0.980
# Validation set F1 score : 0.851
# ===============================================================================
# Class weights : [1, 5], Neighbours : 17
# Validation set Accuracy : 0.979
# Validation set F1 score : 0.846
# ===============================================================================
# Class weights : [1, 5], Neighbours : 19
# Validation set Accuracy : 0.980
# Validation set F1 score : 0.849
# ===============================================================================
# Class weights : [1, 5], Neighbours : 21
# Validation set Accuracy : 0.981
# Validation set F1 score : 0.858
# ===============================================================================
# Class weights : [1, 5], Neighbours : 23
# Validation set Accuracy : 0.981
# Validation set F1 score : 0.859
# ===============================================================================
# Class weights : [1, 5], Neighbours : 25
# Validation set Accuracy : 0.981
# Validation set F1 score : 0.858
# ===============================================================================
# Class weights : [1, 6], Neighbours : 3
# Validation set Accuracy : 0.977
# Validation set F1 score : 0.827
# ===============================================================================
# Class weights : [1, 6], Neighbours : 5
# Validation set Accuracy : 0.972
# Validation set F1 score : 0.805
# ===============================================================================
# Class weights : [1, 6], Neighbours : 7
# Validation set Accuracy : 0.968
# Validation set F1 score : 0.784
# ===============================================================================
# Class weights : [1, 6], Neighbours : 9
# Validation set Accuracy : 0.964
# Validation set F1 score : 0.765
# ===============================================================================
# Class weights : [1, 6], Neighbours : 11
# Validation set Accuracy : 0.964
# Validation set F1 score : 0.766
# ===============================================================================
# Class weights : [1, 6], Neighbours : 13
# Validation set Accuracy : 0.976
# Validation set F1 score : 0.824
# ===============================================================================
# Class weights : [1, 6], Neighbours : 15
# Validation set Accuracy : 0.979
# Validation set F1 score : 0.842
# ===============================================================================
# Class weights : [1, 6], Neighbours : 17
# Validation set Accuracy : 0.979
# Validation set F1 score : 0.846
# ===============================================================================
# Class weights : [1, 6], Neighbours : 19
# Validation set Accuracy : 0.979
# Validation set F1 score : 0.842
# ===============================================================================
# Class weights : [1, 6], Neighbours : 21
# Validation set Accuracy : 0.978
# Validation set F1 score : 0.835
# ===============================================================================
# Class weights : [1, 6], Neighbours : 23
# Validation set Accuracy : 0.978
# Validation set F1 score : 0.840
# ===============================================================================
# Class weights : [1, 6], Neighbours : 25
# Validation set Accuracy : 0.979
# Validation set F1 score : 0.846
# ===============================================================================
# Class weights : [1, 7], Neighbours : 3
# Validation set Accuracy : 0.976
# Validation set F1 score : 0.826
# ===============================================================================
# Class weights : [1, 7], Neighbours : 5
# Validation set Accuracy : 0.972
# Validation set F1 score : 0.806
# ===============================================================================
# Class weights : [1, 7], Neighbours : 7
# Validation set Accuracy : 0.968
# Validation set F1 score : 0.783
# ===============================================================================
# Class weights : [1, 7], Neighbours : 9
# Validation set Accuracy : 0.964
# Validation set F1 score : 0.764
# ===============================================================================
# Class weights : [1, 7], Neighbours : 11
# Validation set Accuracy : 0.961
# Validation set F1 score : 0.749
# ===============================================================================
# Class weights : [1, 7], Neighbours : 13
# Validation set Accuracy : 0.962
# Validation set F1 score : 0.756
# ===============================================================================
# Class weights : [1, 7], Neighbours : 15
# Validation set Accuracy : 0.974
# Validation set F1 score : 0.815
# ===============================================================================
# Class weights : [1, 7], Neighbours : 17
# Validation set Accuracy : 0.978
# Validation set F1 score : 0.835
# ===============================================================================
# Class weights : [1, 7], Neighbours : 19
# Validation set Accuracy : 0.977
# Validation set F1 score : 0.834
# ===============================================================================
# Class weights : [1, 7], Neighbours : 21
# Validation set Accuracy : 0.977
# Validation set F1 score : 0.832
# ===============================================================================
# Class weights : [1, 7], Neighbours : 23
# Validation set Accuracy : 0.975
# Validation set F1 score : 0.821
# ===============================================================================
# Class weights : [1, 7], Neighbours : 25
# Validation set Accuracy : 0.975
# Validation set F1 score : 0.821
# ===============================================================================
# Class weights : [1, 8], Neighbours : 3
# Validation set Accuracy : 0.976
# Validation set F1 score : 0.825
# ===============================================================================
# Class weights : [1, 8], Neighbours : 5
# Validation set Accuracy : 0.972
# Validation set F1 score : 0.806
# ===============================================================================
# Class weights : [1, 8], Neighbours : 7
# Validation set Accuracy : 0.968
# Validation set F1 score : 0.783
# ===============================================================================
# Class weights : [1, 8], Neighbours : 9
# Validation set Accuracy : 0.964
# Validation set F1 score : 0.762
# ===============================================================================
# Class weights : [1, 8], Neighbours : 11
# Validation set Accuracy : 0.961
# Validation set F1 score : 0.750
# ===============================================================================
# Class weights : [1, 8], Neighbours : 13
# Validation set Accuracy : 0.957
# Validation set F1 score : 0.731
# ===============================================================================
# Class weights : [1, 8], Neighbours : 15
# Validation set Accuracy : 0.961
# Validation set F1 score : 0.751
# ===============================================================================
# Class weights : [1, 8], Neighbours : 17
# Validation set Accuracy : 0.973
# Validation set F1 score : 0.808
# ===============================================================================
# Class weights : [1, 8], Neighbours : 19
# Validation set Accuracy : 0.976
# Validation set F1 score : 0.825
# ===============================================================================
# Class weights : [1, 8], Neighbours : 21
# Validation set Accuracy : 0.976
# Validation set F1 score : 0.823
# ===============================================================================
# Class weights : [1, 8], Neighbours : 23
# Validation set Accuracy : 0.975
# Validation set F1 score : 0.819
# ===============================================================================
# Class weights : [1, 8], Neighbours : 25
# Validation set Accuracy : 0.974
# Validation set F1 score : 0.815
# ===============================================================================
# Class weights : [1, 9], Neighbours : 3
# Validation set Accuracy : 0.976
# Validation set F1 score : 0.822
# ===============================================================================
# Class weights : [1, 9], Neighbours : 5
# Validation set Accuracy : 0.973
# Validation set F1 score : 0.807
# ===============================================================================
# Class weights : [1, 9], Neighbours : 7
# Validation set Accuracy : 0.968
# Validation set F1 score : 0.785
# ===============================================================================
# Class weights : [1, 9], Neighbours : 9
# Validation set Accuracy : 0.964
# Validation set F1 score : 0.761
# ===============================================================================
# Class weights : [1, 9], Neighbours : 11
# Validation set Accuracy : 0.961
# Validation set F1 score : 0.748
# ===============================================================================
# Class weights : [1, 9], Neighbours : 13
# Validation set Accuracy : 0.957
# Validation set F1 score : 0.729
# ===============================================================================
# Class weights : [1, 9], Neighbours : 15
# Validation set Accuracy : 0.953
# Validation set F1 score : 0.713
# ===============================================================================
# Class weights : [1, 9], Neighbours : 17
# Validation set Accuracy : 0.959
# Validation set F1 score : 0.741
# ===============================================================================
# Class weights : [1, 9], Neighbours : 19
# Validation set Accuracy : 0.970
# Validation set F1 score : 0.793
# ===============================================================================
# Class weights : [1, 9], Neighbours : 21
# Validation set Accuracy : 0.973
# Validation set F1 score : 0.806
# ===============================================================================
# Class weights : [1, 9], Neighbours : 23
# Validation set Accuracy : 0.973
# Validation set F1 score : 0.812
# ===============================================================================
# Class weights : [1, 9], Neighbours : 25
# Validation set Accuracy : 0.973
# Validation set F1 score : 0.807
# ===============================================================================
# Class weights : [1, 10], Neighbours : 3
# Validation set Accuracy : 0.976
# Validation set F1 score : 0.822
# ===============================================================================
# Class weights : [1, 10], Neighbours : 5
# Validation set Accuracy : 0.972
# Validation set F1 score : 0.805
# ===============================================================================
# Class weights : [1, 10], Neighbours : 7
# Validation set Accuracy : 0.968
# Validation set F1 score : 0.782
# ===============================================================================
# Class weights : [1, 10], Neighbours : 9
# Validation set Accuracy : 0.964
# Validation set F1 score : 0.764
# ===============================================================================
# Class weights : [1, 10], Neighbours : 11
# Validation set Accuracy : 0.960
# Validation set F1 score : 0.746
# ===============================================================================
# Class weights : [1, 10], Neighbours : 13
# Validation set Accuracy : 0.956
# Validation set F1 score : 0.727
# ===============================================================================
# Class weights : [1, 10], Neighbours : 15
# Validation set Accuracy : 0.953
# Validation set F1 score : 0.713
# ===============================================================================
# Class weights : [1, 10], Neighbours : 17
# Validation set Accuracy : 0.949
# Validation set F1 score : 0.700
# ===============================================================================
# Class weights : [1, 10], Neighbours : 19
# Validation set Accuracy : 0.957
# Validation set F1 score : 0.734
# ===============================================================================
# Class weights : [1, 10], Neighbours : 21
# Validation set Accuracy : 0.968
# Validation set F1 score : 0.781
# ===============================================================================
# Class weights : [1, 10], Neighbours : 23
# Validation set Accuracy : 0.971
# Validation set F1 score : 0.796
# ===============================================================================
# Class weights : [1, 10], Neighbours : 25
# Validation set Accuracy : 0.971
# Validation set F1 score : 0.799

# %%
params[str(max(F1_score))], max(F1_score)
# Out:
# ([2, 9], 0.8820722563053851)
